# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

path = "./friends.txt"
text = open(path).read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer="adam")


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# train the model, output generated text after each iteration
for iteration in range(1, 20):
    print()
    print('-' * 80)
    print('Iteration', iteration)
    model.fit(X, y,
              batch_size=256)

    start_index = random.randint(0, len(text) - maxlen - 1)

    for temp in [0.2, 0.5, 0.8]:
        print()
        print('Current temperature:', temp)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('The current seed is: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(300):
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x[0, t, char_indices[char]] = 1.

            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, temp)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Using TensorFlow backend.
# corpus length: 11864
# total chars: 46
# nb sequences: 3942
# Vectorization...
# Build model...
#
# --------------------------------------------------------------------------------
# Iteration 1
# Epoch 1/10
# 3942/3942 [==============================] - 4s - loss: 3.3605
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 3.0821
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 3.0560
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 3.0362
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 3.0014
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 2.9570
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 2.8964
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 2.8221
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 2.7514
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 2.6646
#
# Current temperature: 0.2
# The current seed is: "ebs.
# phoebe: ok, now where's my real pr"
# ebs.
# phoebe: ok, now where's my real pre t ane at  aoe  ohen ehan than eo than ina  ooe  aoe  ane e or ne toe than ere the eo  oon te  oon ee the t an the than eo  ane ere thana an caen aan te  ohan ehe than io to ano ean aoe  ohen e an the to t ano the than ao  hane  ae te  ooe to  ao ee t ea nee t io aae the than ean  oun toe the ane e
#
# Current temperature: 0.5
# The current seed is: "ebs.
# phoebe: ok, now where's my real pr"
# ebs.
# phoebe: ok, now where's my real pre n erat ihang uom a,  oue tan nhrro  eaell
# nonn  on ice ane ia: ay ehen ie toe than ane  te  mare toe eit noe ncan eoe a  oanle cane aar  on nona same caann ee t andene woe acane ahaie foaand mont e wcand are m oeett thancoaeaai coal lnre: aha le pea nou ,co,ss andlle a anoi rbtae  oees  ohun n'g
#
# Current temperature: 0.8
# The current seed is: "ebs.
# phoebe: ok, now where's my real pr"
# ebs.
# phoebe: ok, now where's my real preur tin .handl,onn'  haadle :i
# usj?wnhan shon khe litm mospcurns ei oniagmmcesd
# aaa chman eha ]oi[h,
# olnler moaoe i rr  hasnd hat bo ihey. ictkaidl un pren y? :hee e tun ie uhhe eqhe, ecauts tr eggirhhchanyl insy,s soetc
# wnere. t]anwit vn inat r1aw eachera, manisa
# onnasomme fo roetag na na,lad
#
# --------------------------------------------------------------------------------
# Iteration 2
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 2.6010
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 2.5299
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 2.4702
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 2.4215
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 2.3729
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 2.3183
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 2.2897
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 2.2400
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 2.2050
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 2.1800
#
# Current temperature: 0.2
# The current seed is: "t. what name appears on the address labe"
# t. what name appears on the address labe ind oou ghan whand are hand ing thand erong thand ind are thand ind irang thand are and er andler andler andler and are thand are than in inan whand ar andler and and are the thand are ou thand are ar andler ande thand and ar thand and are and ian ind ind irand ao thand ar indler and ar ind the go
#
# Current temperature: 0.5
# The current seed is: "t. what name appears on the address labe"
# t. what name appears on the address labe and thatg and ithe thandlerrandle frome fous ohat foang
# aoane ohathe
# handler: chandler:
# handler andler
# chandler:
# onss helt ah you
# chandlerr batle ohand
# remeles andlat ing yome goo, woanve changlere oss thand eres as caanteer e wanhe then, whand ohet andlere and ing and, thand ere oou ghanper
#
# Current temperature: 0.8
# The current seed is: "t. what name appears on the address labe"
# t. what name appears on the address labes  irhthe oshnicha ime, ing.
# chandler : ingine het mart noy thandlekdame ingind rorey than'mrsungi iahe woa, andlef:..
# chuclar: phandele oe anverery andie  iupphaidg in the e do hat  ouchingler ohar iok ar.
# caindler: ilg tinan heb's au't  auos "atp. whou aat ware aeres poea doman'tbe'n tan ao er
#
# --------------------------------------------------------------------------------
# Iteration 3
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 2.1495
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 2.1200
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 2.1000
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 2.0715
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 2.0408
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 2.0143
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 1.9789
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.3077
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.2754
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.2561
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.2332
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.2270
#
# Current temperature: 0.2
# The current seed is: "is alone with only one other female coll"
# is alone with only one other female colle puang thaleyt ghat mingt. ir st it hare if ll tue poust dlor aal uedes, thess ik iu the  aaler ben! oons moka gok whal tue anothe it the's ppatriffl tttt's "ithi's ir the bet seleebben...
# joey: what's whyt wat's shat d du to gongen?
# chandler: [a hun ther goss mlite appratesse iom toe kowe the fu
#
# Current temperature: 0.5
# The current seed is: "is alone with only one other female coll"
# is alone with only one other female colle pusk chaddler]
# chandlen bowha dighis nith u d ahay ig ytu to goallu de pheteereanst condirasas  carris]
# poee: wht', wh tule..
# joey: chat'l a wh t'ss, in thet ape bot thepam.iin...
# ross: ihay, the pot th  aminit.... the sepicallly llleeess not'd got ac ouk "hale werllts s "ook chare]n]
# chandle
#
# Current temperature: 0.8
# The current seed is: "is alone with only one other female coll"
# is alone with only one other female colle aou kin's yia gi gitt i oout araytee?
# chandler guss chyyt ware to puvden,
# jhes: what'. as! inglte it puuder oohy
# ross: wha, dudy ipphand wo k o kaghe. whllese,
# chandler: selre gos "hellasee bxmot..
# chandle, minnthendlnon hou kot g gha what.
# phandler bandcaming...
# ross: ikl yuca i'  us tut a
#
# --------------------------------------------------------------------------------
# Iteration 9
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.2151
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.2216
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.2175
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.2030
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.1748
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.1495
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.1340
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.1167
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.1019
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0850
#
# Current temperature: 0.2
# The current seed is: "with a "c!"
# chandler: there just don't "
# with a "c!"
# chandler: there just don't have p matrefnan ounghtoew all efrey iller, in whale pouppan in wimat..
# chandler: ball. [th menit m chandle.
# phsebe wow... chondin: mh tued poonncchandle ppppoendees n" hou'tr ar nrich..... chandle] ss lho, yichirall.
# prasdler ben, towng loon in whame? arachandin.. corecan]
# mose nllo, nndwarkit
#
# Current temperature: 0.5
# The current seed is: "with a "c!"
# chandler: there just don't "
# with a "c!"
# chandler: there just don't hame t m toeng?
# chandler: whan: wall.
# chandler: the , this.
# chandler: the m there ssusthe oundit' got t waand.
# rhas : ahas, what've gate thatee anon'w ahe uokennyyuull yone shenkith me sonsthapkuss toe falra,
# juey?  ithe pot, whet. it my ook wok whale su loust in andied goongt ichine...
# jhey:
#
# Current temperature: 0.8
# The current seed is: "with a "c!"
# chandler: there just don't "
# with a "c!"
# chandler: there just don't have p matring.. [jmenceriss ll ageenng whet, thap?
# chandler: tok manich'mlisennt.
# coandler bamang hnot.
# rachel: you, you you gurd ale pooth poonkma haoke appasenfl ouk mokith wame hh is "enton comithin?
# phaebie: os.
# chandler  anly, who, whe paplf foon.
# chaadler: whly yich andder asonny, iok k
#
# --------------------------------------------------------------------------------
# Iteration 10
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0781
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0688
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0611
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0557
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0522
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0479
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0439
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0412
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0385
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0362
#
# Current temperature: 0.2
# The current seed is: " why do you have to wear underwear tonig"
#  why do you have to wear underwear tonigh ioke the gus aoreyto go...
# roen: [amkit.
# chaidler: tust, in'll the oo ghat gid chrict aal yuller band..
# chandler: we teess dlntceresss foo, i dot, it "i"iintt ingieennnt ouse be pat iff t bo oonni goke ball aler ise nit  ooka d ghe,
# ponyylorass michat'll f oed ano amditt..
# chandler: thl assss
#
# Current temperature: 0.5
# The current seed is: " why do you have to wear underwear tonig"
#  why do you have to wear underwear tonigh iokeve git "aleregntloo, monid's he natewa tu iot, n't kat f fatett ing. bun it yt at'd go dun, nn wome i goong youv gore it mutgit!
# coandler: you's vuall wall sowha that pi god to kanlyeeb.
# josss icha.
# phes: it't  tu't lorerpinh....
# joss: what' ga t iok tn tow ma ithing...
# coenccaan: ss tunn
#
# Current temperature: 0.8
# The current seed is: " why do you have to wear underwear tonig"
#  why do you have to wear underwear tonigh looke ge gue houre gonttheppppepint e.
# chandler: bedn.. who, thats
# rhandlerb conncaarssssst rarace lpopee pton't loars dowht moowham ioe...
# mhender ast ke ehyee's andl..
# chandler: a!
# ressile  ook.
# i'me nam, t'llnt, yousss gonlloraang. int,.
# phandler sincisevidlte whar us lond i'mlithang.
# cha
#
# --------------------------------------------------------------------------------
# Iteration 11
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0347
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0344
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0324
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0312
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0295
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0275
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0255
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0245
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0228
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0216
#
# Current temperature: 0.2
# The current seed is: "e'll give up the birds.
# [joey makes a s"
# e'll give up the birds.
# [joey makes a suodey is  no har alllytedyou ghondwhrrach ndl shengot am you char in whe terranne.
# comes: ok, sidw't lit  ha haud ariche. frfsme ni hate dungith niti gurinn oome dont..
# chandler: [i hundy, wharass chachsre spoppponitc hoo ma gith..
# joey: ookas chandi hss sedsst gi what, tha pit iu gotey ookrcallar
#
# Current temperature: 0.5
# The current seed is: "e'll give up the birds.
# [joey makes a s"
# e'll give up the birds.
# [joey makes a suod, biss se iha yee whotedd an..ichandler bichandye  hare,r!
# jhey: wowh   wa't d wt't faten in... chandeer: whll, whandlersss comeniles, en icevenne ue sound ino.
# rose: iuks.
# chandler: the wedt's  gore gon...
# chandler: be n'e nt oue s mitg's lppoeepbo?
# raseellloo,e hos..
# chandler: the : wid. w
#
# Current temperature: 0.8
# The current seed is: "e'll give up the birds.
# [joey makes a s"
# e'll give up the birds.
# [joey makes a sjoey,
# juse : wherras's ytu toenit sithatn tuepit got .."rachearsss
# cos-y tou' s what?
# chasdler goonsy ooaaa i's so, th pase f maid a...in'y yiaa, te to seube giti.d ar ihg yeaphond tollt semmmt?demtowe mooe.
# poren:: ak, yuch.
# rssse tha raclree!!
# joss: yoo'ran', whkppppaeppoonnt
# roundee roghel
#
# --------------------------------------------------------------------------------
# Iteration 12
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0206
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0195
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0187
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0181
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0175
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0166
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0163
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0157
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0152
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0148
#
# Current temperature: 0.2
# The current seed is: "didn't get to shake my belly like a bowl"
# didn't get to shake my belly like a bowl t laoss noconnichaller oong.
# rhasdler basl you's on, iokh h parisg ntteding noci ngoue non thoe's poyang yeare nom no ow channne malles, no.
# coandler: anll. nht ust fn it aareed o.
# joey: iowha l tuki g yoeenst ghon...
# chandler: sell, y g cound s  it, in iincthinget!eeann..
#
# chandler: we tte th "
#
# Current temperature: 0.5
# The current seed is: "didn't get to shake my belly like a bowl"
# didn't get to shake my belly like a bowl t laoss nconnydrareee noon dore cann oo m aou g aall.
# joey: ao..
# rhas: err tellou's got i''l y aad ou that s  ia nu tullano,. ichmedlerb a lheleer fe ssook thal aa ex ho, thas mangoe goo gonita ime tue  f are te noo. hink we gha d poaerinng they inchandle?
# chandler: [e 'us, thangit's hote, mo gh
#
# Current temperature: 0.8
# The current seed is: "didn't get to shake my belly like a bowl"
# didn't get to shake my belly like a bowl t laoss mcnondlerlas usoonnd rrarige phay,,d auss.
# conndir: ok, the's whand.
# [hye pous ill ale gutdesshong moder coannin.... hhas ieala huro t or andwand im it yenit'.
# ronn:: akkung whal to wantteben?
# chendler bungnt ook  hou''s llyenbeno. joy oonit ghet?
# chandler: telle ou huy wo tha gousch n
#
# --------------------------------------------------------------------------------
# Iteration 13
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0141
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0134
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0128
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0125
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0123
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0119
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0118
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0114
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0110
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0108
#
# Current temperature: 0.2
# The current seed is: "t without that inflatable sheep.
# rachel"
# t without that inflatable sheep.
# rachel: youha wint warr outhe fam.
# coandler anoun ooke  ok ma gaa gh tod too kave whe pusee ount ook roow m ich.i'm..
# chandies gont hangt.
# chandle,  hoves: si's  harrid's lithit's
# caninel: *eeebbeangiedl, ind.
# chaidles: shatke , cheerlarlls joey, io' movea gi ght...
# chandler: bow what.
# chandler: th t
#
# Current temperature: 0.5
# The current seed is: "t without that inflatable sheep.
# rachel"
# t without that inflatable sheep.
# rachel: yhea's urdoue llless werhas.
# chandler: tnytu ge sit ghat?
# chandler: badn aslis the te whrr ponetp hat komyt
# conncon "lllle s baas sowhy  iok what'w ghy urass nit imi an inkt me iamene?
# joeye: ooks: ll''  sar, the...
# rrssilllaay har werpesss gote, ouangee you doun womo, tovenn apoue my ioknawn
#
# Current temperature: 0.8
# The current seed is: "t without that inflatable sheep.
# rachel"
# t without that inflatable sheep.
# rachel: yheha, whataw ard toe pomencone..
# chasbee: su,s,! in. yolv aagu, charldre pouk token goo ph coel"hasi"c"...im'thating ale tuedean!
# chandler: s[ hiokis mite?
# roseb: ou, wer ie wh t i gess,nithlsedeeref om coore aal.
# ross, i kut. w'm tulla geapoud it't  ove a iigh...ithytu tooe ppvandler poon mm
#
# --------------------------------------------------------------------------------
# Iteration 14
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0105
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0103
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0098
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0095
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0092
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0090
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0087
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0084
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0083
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0081
#
# Current temperature: 0.2
# The current seed is: "aybe if i wasn't going commando!
# chandl"
# aybe if i wasn't going commando!
# chandler: ban'.
# [!ushall, gher: chandles nit's irdathiecamiing.
# monica: ahker aall yousss gha am doe! in coonk ot ma't not as uadllo kinh wewawe . wult tea om "ovida. bemesee goo whali a mi ait..
# jhey: [alss chandlwre gh ley ay uroot, monhy.
# roes  ivvaler, what ha piutt oung ooem ino maninn ...
# chasnn
#
# Current temperature: 0.5
# The current seed is: "aybe if i wasn't going commando!
# chandl"
# aybe if i wasn't going commando!
# chandler: bag.
# chas, whass oedlr aedletsis goey, wiramin.... hhe what  am tuets nonessing thengit, phappeabe pfris mone bofrabd?
# chandler: *ull:  thee's shan't
# connceraandy, lle, be pami t on courkanng the goag undt. it me toknig mithen to challler: the momich..
# chandler: at ik moithi g ave ller iee?..
#
# Current temperature: 0.8
# The current seed is: "aybe if i wasn't going commando!
# chandl"
# aybe if i wasn't going commando!
# chandler: bga!
# [ass. chandi's sh pithi g at eidt be...
# chandler: ss the t!
# chandler: sunt  koou g yoo. moverebpout?
# pouydil  oo  juvie idghte?
# chandler: tu ghow wharr ghat soust  ivaal]
# phcelle : tuss.
# rrasbee? bin's bove,
# chasdeer is jas  ooo.
# coandler: the  uif ik nou thent,
# pheebel  out  ou .
#
# --------------------------------------------------------------------------------
# Iteration 15
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0081
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0079
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0084
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0468
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 1.5742
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 1.4794
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 1.1835
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.9682
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.7722
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.6359
#
# Current temperature: 0.2
# The current seed is: ": unfortunately, that would be correct. "
# : unfortunately, that would be correct. "oo..
# chandler: what, what se ra lous tharose ppoetre tand thong t ar in ma dit tal ko aallure tha keregt llore bel ther as prfrth pous, what it it it it it it it it it it it in it matee?
# chandler: is henot, whand tom gos ond are the pererpannt.
# chandler: the ketheles bend the gondwerring y mouid
#
# Current temperature: 0.5
# The current seed is: ": unfortunately, that would be correct. "
# : unfortunately, that would be correct. "oo..
# ross: ive you dure now mat'e not whar maller gonse dokath geme pomet hanetha doos, charanil  prosst lat th ous, drachellss
# phoese: go, whond whan thame..... choemes] "ok kall all t es under got pount iok amla, go...
# coandler bang, [e kin't rare nom.
# chandler: shl-, the foyy, d't it an io n
#
# Current temperature: 0.8
# The current seed is: ": unfortunately, that would be correct. "
# : unfortunately, that would be correct. "oulerd younthing wir?
# chandler blicha, the.
# rhandler goo, chandler ss llved, the josth toer ngteed fromccheleasleally yound chandler sslendy donss chare as "mendeer bon chandler be liokn'  goe cabina.... hereee gochemdler
# chandler: 1ul is onowhat't gat, i'm lond io gu gey igey, you widknt m.
# ro
#
# --------------------------------------------------------------------------------
# Iteration 16
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.5198
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.4321
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.3517
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.2877
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.2497
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.2115
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.1660
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.1350
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.1074
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0902
#
# Current temperature: 0.2
# The current seed is: "eague, wendy, and monica is worried abou"
# eague, wendy, and monica is worried abouedin........
# chandler: [hlved and the ust ghe pppiiclale t aoo yamllo's gom chanello.
# joey: you' soud ithe bedde.
# chandler: thank what ladle oon chomanit  haus, donst, ik nhi hhase poontcainnt... where, ama he tit ia guvy oul you ght 's aray,
# usss pooe all age "...
# ross ingo, it hare wa pouss c
#
# Current temperature: 0.5
# The current seed is: "eague, wendy, and monica is worried abou"
# eague, wendy, and monica is worried abouedin.......
# chandler: shly wear in think tha gonyer and en the ouy it vearaappr beppes ang ou y ooker'dley,
# hees: rast llaatee do rascouss
# ross: i glttee ao puodin.
# ross: aras, it'l ure that is indin's on camene]
# pheyditgote nttidi's mingit.
# poney: ak, thit sit th ou githe, gus found thamd in
#
# Current temperature: 0.8
# The current seed is: "eague, wendy, and monica is worried abou"
# eague, wendy, and monica is worried aboue tountt taf oua i ou tu, gutder andenonyt
# comnica: may, de ts ponttari g you' goo kamlie's longit? areat, inh..
# ross: phas, thes fross,
# chaidler: whel sellt ea*lle qrych leee ss hadl,.
# chandler: the gust ge oung. iok,, the where sanst dle now
# vhand ppaspentt thave waat u'dly uoe's gey?urdrass
#
# --------------------------------------------------------------------------------
# Iteration 17
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0770
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0724
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0676
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0549
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0454
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0397
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0354
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0317
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0289
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0267
#
# Current temperature: 0.2
# The current seed is: "something. joker is poker with a j... co"
# something. joker is poker with a j... coinnicam ite ti guteene go. chondler: suy y lorr ghaled?
# chandler: the to, chand?
# poss: chanderr ss nnteydunget ep ooeycondennnthe na dungoe chonette pporestul!
# chandler: wu ctentt ss it it kame i  itesybenge.
# joey: yowha , wh t wo'w dlon's hote ta leryito...
# joes: whare, wh.. i'd nn the paatee
#
# Current temperature: 0.5
# The current seed is: "something. joker is poker with a j... co"
# something. joker is poker with a j... cointiean t mate t loos angoededlond yomeze's uh iow allyregeas pootdllra]
# phoey: wht, thas what i  oonyt'mg te ming....
# chandler: thal's batlee fank.
# jhen: wall u git, ir in yur aadern ttous oo goveraring slout it ound oud in yuu too guvl are pheereftes onoyyllaressm chat ef onat ouk akdou's  oomyt
#
# Current temperature: 0.8
# The current seed is: "something. joker is poker with a j... co"
# something. joker is poker with a j... cointiean t mithet tavgu?
# chandler bang oung tey und y all ere ifmy, to'm coandlar ai h yora i'm ind.
# romee: yous llore ig's deyt t ard erbedelp!
# joss: inchase hom til, ongy corerrabee phatsef foppkssithhass poard you theo'w haler bithef ou gith tllr aakerrichll thed as shfriss
# loadd you. yorass,
#
# --------------------------------------------------------------------------------
# Iteration 18
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0251
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0237
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0224
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0209
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0197
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0186
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0179
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0170
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0163
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0154
#
# Current temperature: 0.2
# The current seed is: "thout that inflatable sheep.
# rachel: ye"
# thout that inflatable sheep.
# rachel: yeahe wachiull y ouss chale te pha,..
# chandler: the tund whnt iom an you whar wo laokey i  ho keva liee.
# joey: oo, chin'ss he has?
# chandler: be ne... whand wa g ouk ay u de te touss "ooncarrea] bfles bundlerest no. wharea'!
# chandler bang.
# chandler: well, bennce peress "oony i a kr gha s mesinnnt.
#
# Current temperature: 0.5
# The current seed is: "thout that inflatable sheep.
# rachel: ye"
# thout that inflatable sheep.
# rachel: yeaha whall, whaps fok  ooke ald ghe.
# ponye: oo, mo an wh whas what, wh the past ghon..
#
# rhasdler: the toowhall are oo *houk s pire].
# joeyy: co'r: we, wh the ress d youncernen you gonnntwhat i m courelyo hamyye dour gha big ihepongges ohal treaphsu dot s ik and wha t.
# chandler bhas whantle you conn
#
# Current temperature: 0.8
# The current seed is: "thout that inflatable sheep.
# rachel: ye"
# thout that inflatable sheep.
# rachel: yeahe wall elll oos mok tadd as "ict'elllt, aslemldo, indom witt e mange nou t doon har gheipe faret oentet us ing ro in lereas pooy.
# coand ar yie yly counn an th coonda nate hx ot
# chandler: shlly, ghe shele's fondy, ohe mmi't har andlerdben jusch tell wa lemhetenss chandler: wht ke sss gokenntw ma
#
# --------------------------------------------------------------------------------
# Iteration 19
# Epoch 1/10
# 3942/3942 [==============================] - 3s - loss: 0.0149
# Epoch 2/10
# 3942/3942 [==============================] - 3s - loss: 0.0144
# Epoch 3/10
# 3942/3942 [==============================] - 3s - loss: 0.0142
# Epoch 4/10
# 3942/3942 [==============================] - 3s - loss: 0.0135
# Epoch 5/10
# 3942/3942 [==============================] - 3s - loss: 0.0129
# Epoch 6/10
# 3942/3942 [==============================] - 3s - loss: 0.0123
# Epoch 7/10
# 3942/3942 [==============================] - 3s - loss: 0.0126
# Epoch 8/10
# 3942/3942 [==============================] - 3s - loss: 0.0118
# Epoch 9/10
# 3942/3942 [==============================] - 3s - loss: 0.0111
# Epoch 10/10
# 3942/3942 [==============================] - 3s - loss: 0.0108
#
# Current temperature: 0.2
# The current seed is: "pposite of taking somebody's underwear! "
# pposite of taking somebody's underwear!
# joey: ooka m you d ou tur goude tous s yoallard andyeud enone slloke, memyeeler benyeunden, thavkey aciundlll phessss houyyu dure ia mundler bho she heress lllassss corallee: whas iddnt.
# conicl: m thet weat y u dont what e mot i'ml te befous?
# chandler bung whot.
# chandler: shet, te thller
# rhss:
#
# Current temperature: 0.5
# The current seed is: "pposite of taking somebody's underwear! "
# pposite of taking somebody's underwear!
# joey: anal. llon itlle digh wore t an yionywarie nmy hereas?
# chandler: all mono. what we phouss ding... choudler]
# aonyy  oou chale]
# chandler  ount wewh wh t wha'd  arracden'.
# joey: we thes wing ond too k mooee ppat in t tt tount mavea??
# chandler  ooks mode, what.
# rhand er as, joey
# chandler:
#
# Current temperature: 0.8
# The current seed is: "pposite of taking somebody's underwear! "
# pposite of taking somebody's underwear!
# joey: caand  m st, what'  harere nous sjongo, charens]: fryer ahane t oke iow ghee?
# chandler: now, meandleass dno.
# conddlar: sount ichannteed foust tha  allrr's lal uu! youey og gnde bet?
# chandler: oom monow mite...
# joey: who, what i' l teepfane sonets nom tot kaam migh... hho me wont i lla'r
